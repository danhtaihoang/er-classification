# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
np.random.seed(1)

# %%
data_name_list = ['nki','peptide','amputation','wisconsin','heat','hc','paradox','school','stigma','ef',\
                 'smok','coag','anemia','cervix','mental','dement','septic','coimbra','cryo','somerville',\
                  'hcc','heart','liver','language']
n_data = len(data_name_list)

# %%
print('accuracy:')

nx,ny = 4,5
nfig = nx*ny
fig, ax = plt.subplots(ny,nx,figsize=(nx*3.5,ny*2.8))

t = 0
ij = 0
for i in range(nx):
    for j in range(ny):    
        
        data_name = data_name_list[ij]
        acc = np.loadtxt('result/%s_acc.dat'%data_name)
        acc_LR = np.loadtxt('result/%s_acc_LR.dat'%data_name)

        ax[j,i].bar(0,acc_LR[t],color='b',width=0.8,label='LR')
        ax[j,i].bar(1,acc[t],color='r',width=0.8,label='ER')
        ax[j,i].set_xlabel('0: LR , 1: ER')
        ax[j,i].set_title('%s: %2.2f, %2.2f'%(data_name,acc_LR[t],acc[t]),np.sign(acc[t]-acc[t]))

        ij += 1

plt.tight_layout(h_pad=1, w_pad=1.5)
#plt.savefig('acc.pdf', format='pdf', dpi=100)

# %%
print('AUC:')

nx,ny = 4,5
nfig = nx*ny
fig, ax = plt.subplots(ny,nx,figsize=(nx*3.5,ny*2.8))

ij = 0
for i in range(nx):
    for j in range(ny):    
        
        data_name = data_name_list[ij]
        acc = np.loadtxt('result/%s_acc.dat'%data_name)
        acc_LR = np.loadtxt('result/%s_acc_LR.dat'%data_name)

        ax[j,i].bar(0,acc_LR[1],color='b',width=0.8,label='LR')
        ax[j,i].bar(1,acc[1],color='r',width=0.8,label='ER')
        ax[j,i].set_xlabel('0: LR , 1: ER')
        ax[j,i].set_title('%s: %2.2f, %2.2f'%(data_name,acc_LR[0],acc[0]))

        ij += 1

plt.tight_layout(h_pad=1, w_pad=1.5)
#plt.savefig('auc.pdf', format='pdf', dpi=100)

# %%
print('precision:')

nx,ny = 4,5
nfig = nx*ny
fig, ax = plt.subplots(ny,nx,figsize=(nx*3.5,ny*2.8))

ij = 0
for i in range(nx):
    for j in range(ny):    
        
        data_name = data_name_list[ij]
        acc = np.loadtxt('result/%s_acc.dat'%data_name)
        acc_LR = np.loadtxt('result/%s_acc_LR.dat'%data_name)

        ax[j,i].bar(0,acc_LR[2],color='b',width=0.8,label='LR')
        ax[j,i].bar(1,acc[2],color='r',width=0.8,label='ER')
        ax[j,i].set_xlabel('0: LR , 1: ER')
        ax[j,i].set_title('%s: %2.2f, %2.2f'%(data_name,acc_LR[0],acc[0]))

        ij += 1

plt.tight_layout(h_pad=1, w_pad=1.5)
#plt.savefig('precision.pdf', format='pdf', dpi=100)

# %%
print('recall:')
nx,ny = 4,5
nfig = nx*ny
fig, ax = plt.subplots(ny,nx,figsize=(nx*3.5,ny*2.8))

ij = 0
for i in range(nx):
    for j in range(ny):    
        
        data_name = data_name_list[ij]
        acc = np.loadtxt('result/%s_acc.dat'%data_name)
        acc_LR = np.loadtxt('result/%s_acc_LR.dat'%data_name)

        ax[j,i].bar(0,acc_LR[3],color='b',width=0.8,label='LR')
        ax[j,i].bar(1,acc[3],color='r',width=0.8,label='ER')
        ax[j,i].set_xlabel('0: LR , 1: ER')
        ax[j,i].set_title('%s: %2.2f, %2.2f'%(data_name,acc_LR[0],acc[0]))

        ij += 1

plt.tight_layout(h_pad=1, w_pad=1.5)
#plt.savefig('precision.pdf', format='pdf', dpi=100)
